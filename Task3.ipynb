# %% [markdown]
# ## Future Interns Task 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_feedback.csv')

# %%
df
# Out:
#        S/N  Student ID  Well versed with the subject  \
# 0        1         340                             5
# 1        2         253                             6
# 2        3         680                             7
# 3        4         806                             9
# 4        5         632                             8
# ...    ...         ...                           ...
# 996    997          55                             8
# 997    998         913                             5
# 998    999         199                             9
# 999   1000         539                            10
# 1000  1001         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# ...

# %%
df_cleaned = df.drop(columns=["S/N", "Student ID"])

# %%
df_cleaned
# Out:
#       Well versed with the subject  \
# 0                                5
# 1                                6
# 2                                7
# 3                                9
# 4                                8
# ...                            ...
# 996                              8
# 997                              5
# 998                              9
# 999                             10
# 1000                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# 4                                             10                     8
# ...                                          ...                   ...
# ...

# %%
average_ratings = df_cleaned.mean().sort_values(ascending=False)

# %%
average_ratings
# Out:
# Well versed with the subject                            7.497502
# Explains concepts in an understandable way              6.081918
# Use of presentations                                    5.942058
# Provides support for students going above and beyond    5.662338
# Structuring of the course                               5.636364
# Course recommendation based on relevance                5.598402
# Solves doubts willingly                                 5.474525
# Degree of difficulty of assignments                     5.430569
# dtype: float64

# %%
plt.figure(figsize=(10, 7))
average_ratings.plot(kind='bar')
plt.title("Average Ratings per Feedback Category")
plt.ylabel("Average Score")
plt.xticks(rotation=35)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 9))
sns.heatmap(df_cleaned.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Feedback Categories")

plt.xticks(rotation=35)
plt.tight_layout()
plt.show()

# %%
df["Overall Rating"] = df.drop(columns=["Student ID"]).mean(axis=1)

# %%
df["Overall Rating"].plot.hist(bins=10, color='skyblue', edgecolor='black', figsize=(10, 6))
plt.title("Distribution of Overall Ratings")
plt.xlabel("Average Rating")
plt.tight_layout()
plt.show()

# %%
top_3 = average_ratings.head(3)
bottom_3 = average_ratings.tail(3)

# %%
top_3
# Out:
# Well versed with the subject                  7.497502
# Explains concepts in an understandable way    6.081918
# Use of presentations                          5.942058
# dtype: float64

# %%
bottom_3
# Out:
# Course recommendation based on relevance    5.598402
# Solves doubts willingly                     5.474525
# Degree of difficulty of assignments         5.430569
# dtype: float64

# %%
df["Course recommendation based on relevance"].value_counts(
    bins=[0, 4, 7, 10], sort=True
).plot.pie(
    labels=["Low (1–4)", "Medium (5–7)", "High (8–10)"],
    autopct='%1.1f%%',
    startangle=140,
    colors=["Red", "Yellow", "lightgreen"]
)
plt.title("Recommendation Score Distribution")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
df["Overall Rating"].describe()
# Out:
# count    1001.000000
# mean       60.924853
# std        32.127932
# min         4.222222
# 25%        33.111111
# 50%        61.111111
# 75%        88.555556
# max       116.444444
# Name: Overall Rating, dtype: float64
